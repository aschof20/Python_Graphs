# %% [markdown]
# # Python Line Plot
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ## Import Data

# %%
data_frame_1 = pd.read_csv('df1', index_col=0)
data_frame_2 = pd.read_csv('df2')

# %% [markdown]
# ## Line Plot

# %%
data_frame_1.plot.line( y='B', figsize=(8,6), lw=0.5)
# Out:
# <AxesSubplot:>
