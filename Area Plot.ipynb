# %% [markdown]
# # Python Area Plot
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ## Import Data

# %%
data_frame_1 = pd.read_csv('df1', index_col=0)
data_frame_2 = pd.read_csv('df2')

# %% [markdown]
# ## Area Plot

# %%
data_frame_2.plot.area()
# Out:
# <AxesSubplot:>

# %%
data_frame_2.plot.area(alpha=0.4)
# Out:
# <AxesSubplot:>
