# %% [markdown]
# # Python Scatter Plot
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ## Import Data

# %%
data_frame_1 = pd.read_csv('df1', index_col=0)
data_frame_2 = pd.read_csv('df2')

# %%
data_frame_1.plot.scatter(x='A',y='B')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
data_frame_1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
data_frame_1.plot.scatter(x='A', y='B', s=data_frame_1['C']*50)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/collections.py:922: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <AxesSubplot:xlabel='A', ylabel='B'>

# %% [markdown]
# ## Scatter Plot - Type II

# %% [markdown]
# ## Install Libraries
# `pip install plotly`
# `pip install cufflinks`

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

import cufflinks as cf
init_notebook_mode(connected=True)


cf.go_offline()
data = pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.6.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.6.3.min']
#             }
#         });
# ...

# %%
data.iplot(kind='scatter',x='A',y='B',mode='markers',size=10)
# Out:
# <div>                            <div id="ee95219f-d68a-4107-be31-fda51f615cde" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
data.iplot(kind='bubble',x='A',y='B',size='C')
# Out:
# <div>                            <div id="0cbd5fd3-e188-47a7-bfa8-915b5c0bfec6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
